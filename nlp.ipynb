# %%
import requests
from bs4 import BeautifulSoup
import nltk
import collections
import lxml
import html5lib
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer
import string
import csv
import re
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tatapie\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tatapie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\tatapie\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
cList = {
  "ain't": "am not",
  "aren't": "are not",
  "can't": "cannot",
  "can't've": "cannot have",
  "'cause": "because",
  "could've": "could have",
  "couldn't": "could not",
  "couldn't've": "could not have",
  "didn't": "did not",
  "doesn't": "does not",
  "don't": "do not",
  "hadn't": "had not",
  "hadn't've": "had not have",
  "hasn't": "has not",
  "haven't": "have not",
  "he'd": "he would",
  "he'd've": "he would have",
  "he'll": "he will",
  "he'll've": "he will have",
  "he's": "he is",
  "how'd": "how did",
  "how'd'y": "how do you",
  "how'll": "how will",
  "how's": "how is",
  "I'd": "I would",
  "I'd've": "I would have",
  "I'll": "I will",
  "I'll've": "I will have",
  "I'm": "I am",
  "I've": "I have",
  "isn't": "is not",
  "it'd": "it had",
  "it'd've": "it would have",
  "it'll": "it will",
  "it'll've": "it will have",
  "it's": "it is",
  "let's": "let us",
  "ma'am": "madam",
  "mayn't": "may not",
  "might've": "might have",
  "mightn't": "might not",
  "mightn't've": "might not have",
  "must've": "must have",
  "mustn't": "must not",
  "mustn't've": "must not have",
  "needn't": "need not",
  "needn't've": "need not have",
  "o'clock": "of the clock",
  "oughtn't": "ought not",
  "oughtn't've": "ought not have",
  "shan't": "shall not",
  "sha'n't": "shall not",
  "shan't've": "shall not have",
  "she'd": "she would",
  "she'd've": "she would have",
  "she'll": "she will",
  "she'll've": "she will have",
  "she's": "she is",
  "should've": "should have",
  "shouldn't": "should not",
  "shouldn't've": "should not have",
  "so've": "so have",
  "so's": "so is",
  "that'd": "that would",
  "that'd've": "that would have",
  "that's": "that is",
  "there'd": "there had",
  "there'd've": "there would have",
  "there's": "there is",
  "they'd": "they would",
  "they'd've": "they would have",
  "they'll": "they will",
  "they'll've": "they will have",
  "they're": "they are",
  "they've": "they have",
  "to've": "to have",
  "wasn't": "was not",
  "we'd": "we had",
  "we'd've": "we would have",
  "we'll": "we will",
  "we'll've": "we will have",
  "we're": "we are",
  "we've": "we have",
  "weren't": "were not",
  "what'll": "what will",
  "what'll've": "what will have",
  "what're": "what are",
  "what's": "what is",
  "what've": "what have",
  "when's": "when is",
  "when've": "when have",
  "where'd": "where did",
  "where's": "where is",
  "where've": "where have",
  "who'll": "who will",
  "who'll've": "who will have",
  "who's": "who is",
  "who've": "who have",
  "why's": "why is",
  "why've": "why have",
  "will've": "will have",
  "won't": "will not",
  "won't've": "will not have",
  "would've": "would have",
  "wouldn't": "would not",
  "wouldn't've": "would not have",
  "y'all": "you all",
  "y'alls": "you alls",
  "y'all'd": "you all would",
  "y'all'd've": "you all would have",
  "y'all're": "you all are",
  "y'all've": "you all have",
  "you'd": "you had",
  "you'd've": "you would have",
  "you'll": "you you will",
  "you'll've": "you you will have",
  "you're": "you are",
  "you've": "you have"
}

c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expandContractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    return c_re.sub(replace, text.lower())

# %%
#Headers will make it look like you are using a web browser
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36'}

#list of restaurants we scrape reviews from
links = []
#reviewnum = []

address = 'https://www.yelp.com/search?find_desc=&find_loc=San+Francisco%2C+CA&ns=1'
response = requests.get(address, headers=headers, verify=False).text
soup = BeautifulSoup(response,"html5lib")
for s in soup.find_all("a", attrs={"class": "lemon--a__373c0__IEZFH link__373c0__29943 link-color--blue-dark__373c0__1mhJo link-size--inherit__373c0__2JXk5"}):
    links.append(s.get('href'))

    #reviewnum.append(r.string)

print(len(links))
print(links[10])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 20
# /biz/hog-island-oyster-co-san-francisco

# %%
import re
#We will use the iteration to retrieve and scrape the web pages, reviews, and ratings from each page on Yelp
reviews = []
ratings = []

totalnum = 0
flag = False

for link in links:
    url = 'https://www.yelp.com' + link
    print(url)
    response = requests.get(url, headers=headers, verify=False).text
    soup = BeautifulSoup(response, "html5lib")
    
    if soup.title.string == "Redirecting...":
        print(soup)
        newurl = soup.a.get('href')
        print(newurl)
        response = requests.get(newurl, headers=headers, verify=False).text
        soup = BeautifulSoup(response, "html5lib")
     
    #print(soup)
    text = soup.find_all("span",attrs={'class': 'dropdown_toggle-text js-dropdown-toggle-text'})
    reviewsnum = str(text[1].string)
    print(reviewsnum)
    #reviewsnum = re.sub("\D", "", reviewsnum)
    reviewsnum = "".join(filter(str.isdigit, reviewsnum))
    #reviewsnum = re.search(r'\d+', reviewsnum).group()
    print(reviewsnum)

    for i in range (0,int(reviewsnum),20):
        fullurl = (url + '?start={}').format(i)
        response = requests.get(fullurl, headers=headers, verify=False).text
        soup = BeautifulSoup(response, "html5lib")
    #Looping through 'div' 'review-content' will help find all the review containers we need in each page that have rating and review
        for s in soup.find_all("div", attrs={'class': 'review-content'}):
            re = s.find('p', attrs={'lang': 'en'})
    #Makes all the letters lower in reviews
            review = re.text.lower()
    #expandContractions will put the dictionary made earlier to replace the contractions in the reviews
    #Make sure to to run the cList dict cell or else there will be an error
            expandContractions(review)
    #Cleaning the lemmas or words in reviews now will make it easier when we start predictive modeling
            words = word_tokenize(review)
            words = word_tokenize(review.replace('\n',' '))
            clean_words = [word.lower() for word in words if word not in set(string.punctuation)]
            characters_to_remove = ["''",'``','...']
            clean_words = [word for word in clean_words if word not in set(characters_to_remove)]
            english_stops = set(stopwords.words('english'))
            clean_words = [word for word in clean_words if word not in english_stops]
            wordnet_lemmatizer = WordNetLemmatizer()
            lemma_list = [wordnet_lemmatizer.lemmatize(word) for word in clean_words]
            reviews.append(lemma_list)
    #Here we are using a simple control flow to recode the ratings for our model. If rating is greater than 3 positive, else negative   
            rating = s.find_all('img', attrs={'class': 'offscreen'})
    #the rating is actually an image, so we need to convert it into a string and then to an integer
            rate = str(rating)
            int_rating = int(rate[11:12])

            if int_rating == 1 or int_rating == 2 or int_rating == 3:
                rating = 'neg'
                ratings.append('neg')
            elif int_rating == 4 or int_rating == 5:
                rating = 'pos'
                ratings.append('pos')
            totalnum = totalnum + 1

            if totalnum >= 5000:
                flag = True
                break
        if flag:
            break
    if flag:
        break
# Out:
# https://www.yelp.com/biz/bi-rite-creamery-san-francisco
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# English (9423)
# 9423
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
#Making sure the number of reviews and ratings match before we append them for our featureset
print(len(reviews))
print(len(ratings))
print(reviews[0])
print(ratings[0])
# Out:
# 5000
# 5000
# ['mine', 'waffle', 'bowl', 'waffle', 'ice', 'cream', 'delicious', 'appreciated', 'waffle', 'stale', 'ice', 'cream', 'super', 'smooth', 'score', 'high', 'presentation', 'better', 'flavor', 'lot', 'place', "'ve"]
# pos

# %%
import re
with open('datatian.txt', 'w') as file:
    for i in range(0, 5000):
        for j in reviews[i]:
            try:
                file.write(j)
            except UnicodeError:
                print("emoji")
            else:
                file.write(",")
        file.write("\n")
        file.write(ratings[i])
        file.write("\n")
        
file.close()
# Out:
# emoji

# %%
reviews = []
ratings = []
with open('datatian.txt', 'r') as file_to_read:
  while True:
    line = file_to_read.readline() # read data from whole role
    if not line:
      break
    review = []
    for i in line.split(','):
        if i != '\n':
            review.append(i)
    reviews.append(review)
    
    line = file_to_read.readline()
    for i in line.split(','):
        if i != '\n':
            ratings.append(i)

file_to_read.close()
print(len(reviews))
print(reviews[0])
print(reviews[1000])
print(len(ratings))
print(ratings[0])
# Out:
# 5000
# ['mine', 'waffle', 'bowl', 'waffle', 'ice', 'cream', 'delicious', 'appreciated', 'waffle', 'stale', 'ice', 'cream', 'super', 'smooth', 'score', 'high', 'presentation', 'better', 'flavor', 'lot', 'place', "'ve"]
# ['could', 'care', 'le', 'ice', 'cream', 'came', 'fell', 'love', 'salted', 'caramel', 'strawberry', 'balsamic', 'let', 'tell', 'must', 'try', 'salted', 'caramel', 'liked', 'better', 'strawberry', 'balsamic', 'although', 'strawberry', 'balsamic', 'deliciousness']
# 5000
# pos

# %%
def open_dict(Dict = '123', path = 'C:\\Users\\tatapie\\Desktop\\ZichaoTian\\opinion-lexicon-English\\'):
    path = path + '%s.txt' %Dict
    dictionary = open(path, 'r', encoding='utf-8',errors='ignore')
    #print(dictionary)
    dict = []
    num = 1
    for word in dictionary:
        word = word.strip('\n')
        if num >= 36:
            dict.append(word)
        num += 1
    return dict

negdict = open_dict('negative-words')
posdict = open_dict('positive-words')
print(len(negdict))
print(len(posdict))
# Out:
# 4783
# 2007

# %%
def score(reviews):
    rate = []
    for review in reviews:
        count = 0

        for word in review:
            if word in posdict:
                count +=1
               
            elif word in negdict:
                count -= 1
        
        if count >= 0:
            rate.append('pos')
        else:
            rate.append('neg')

    return rate

sentirate = score(reviews)
print(len(sentirate))
# Out:
# 5000

# %%
from sklearn.feature_extraction.text import CountVectorizer

x_sen = []
for review in reviews:
    sen = ''
    for word in review:
        sen = sen + word + ' '
        #print(sen)
    x_sen.append(sen)

#print(x_sen[5])
vectorizer = CountVectorizer()
smatrix = vectorizer.fit_transform(x_sen).toarray()
#print(len(smatrix_train[5,]))
print(len(smatrix))
# Out:
# 5000

# %%
import random

testnum = random.sample(range(0, 4999), 1000)
trainnum = list(range(5000))
#print(len(smatrix))
#print(len(ratings))
#print(len(sentirate))
x_test = []
x_train = []
y1_test = []
y2_test = []
y1_train = []
y2_train = []

for i in testnum:
    #print(i)
    x_test.append(smatrix[i])
    y1_test.append(ratings[i])
    y2_test.append(sentirate[i])
    trainnum.remove(i)

for j in trainnum:
    x_train.append(smatrix[j])
    y1_train.append(ratings[j])
    y2_train.append(sentirate[j])

print(len(x_train))
print(x_train[5])
print(len(x_test))
print(len(y1_train))
print(len(y2_test))
print(y1_train[5])
# Out:
# 4000
# [0 0 0 ... 0 0 0]
# 1000
# 4000
# 1000
# pos

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import classification_report, confusion_matrix

#label of stars
clf1 = BernoulliNB()
clf1.fit(x_train, y1_train)
#print accuracy of star labels
print("Accuracy of star labels: " + str(clf1.score(x_test,y1_test)))
#print confusion matrix of star labels
y1_pred = clf1.predict(x_test)
cm1 = confusion_matrix(y1_test,y1_pred)
print("Confusion matrix of star labels:")
print(cm1)

#label of sentiment scores
clf2 = BernoulliNB()
clf2.fit(x_train, y2_train)
print("Accuracy of sentiment labels: " + str(clf2.score(x_test,y2_test)))
#print confusion matrix of sentiment labels
y2_pred = clf2.predict(x_test)
cm2 = confusion_matrix(y2_test,y2_pred)
print("Confusion matrix of sentiment labels:")
print(cm2)
# Out:
# Accuracy of star labels: 0.904
# Confusion matrix of star labels:
# [[ 12  75]
#  [ 21 892]]
# Accuracy of sentiment labels: 0.947
# Confusion matrix of sentiment labels:
# [[  1  45]
#  [  8 946]]

# %%
#Fit model using unigram and NBC
rl = zip(reviews,ratings)

#define a bag_of_words function to return word, True.

def bag_of_words(words):
    return dict([(word, True) for word in words])

# Define another function that will return words that are in words, but not in badwords

def bag_of_words_not_in_set(words, badwords):
    return bag_of_words(set(words) - set(badwords))

from nltk.corpus import stopwords

#define a bag_of_non_stopwords function to return word, True.

def bag_of_non_stopwords(words, stopfile='english'):
    badwords = stopwords.words(stopfile)
    return bag_of_words_not_in_set(words, badwords)

#Creating our unigram featureset dictionary for modeling

uni_featureset = []

for k, v in rl:
    bag_of_words(k)
    uni_featureset.append((bag_of_words(k),v))

import random
random.shuffle(uni_featureset)

#splits the data around 70% of 500 *350 reviews* for both testing and training

train_set, test_set = uni_featureset[0:4000], uni_featureset[4000:]

#Now we will calculate accuracy, precision, recall, and f-measure using Naives Bayes classifier
#This will also show the top 10 most informative features of our featureset

import nltk
import collections
from nltk.metrics.scores import (accuracy, precision, recall, f_measure)
nb_classifier = nltk.NaiveBayesClassifier.train(train_set)
nb_classifier.show_most_informative_features(10)

from nltk.classify.util import accuracy
print(accuracy(nb_classifier, test_set))

refsets = collections.defaultdict(set)
testsets = collections.defaultdict(set)
    
for i, (uni_featureset, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = nb_classifier.classify(uni_featureset)
    testsets[observed].add(i)
    
print('pos precision:', precision(refsets['pos'], testsets['pos']))
print('pos recall:', recall(refsets['pos'], testsets['pos']))
print('pos F-measure:', f_measure(refsets['pos'], testsets['pos']))
print('neg precision:', precision(refsets['neg'], testsets['neg']))
print('neg recall:', recall(refsets['neg'], testsets['neg']))
print('neg F-measure:', f_measure(refsets['neg'], testsets['neg']))
# Out:
# Most Informative Features
#            underwhelming = True             neg
#  : pos
#    =     33.8 : 1.0
#               creativity = True             neg
#  : pos
#    =     27.6 : 1.0
#                      meh = True             neg
#  : pos
#    =     23.5 : 1.0
#                      ..i = True             neg
#  : pos
#    =     21.5 : 1.0
#                     ohio = True             neg
#  : pos
#    =     21.5 : 1.0
#                     bake = True             neg
#  : pos
#    =     21.5 : 1.0
#                    ferry = True             neg
#  : pos
#    =     21.5 : 1.0
#                   safety = True             neg
#  : pos
#    =     21.5 : 1.0
#             additionally = True             neg
#  : pos
#    =     21.5 : 1.0
#                    dunno = True             neg
#  : pos
#    =     21.5 : 1.0
# 0.793
# pos precision: None
# pos recall: None
# pos F-measure: None
# neg precision: None
# neg recall: None
# neg F-measure: None
